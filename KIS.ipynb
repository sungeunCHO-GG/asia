# %%
import pandas as pd

# %%
pd.read_excel('c:/chosungeun/aaa1.xls')
# Out:
#         KIS   Stock                              Name    매출액/121000  \
# 0    001402   36460                            한국가스공사  2.548199e+13
# 1    001471   33780                          (주)케이티앤지  2.821671e+12
# 2    003316   33660                          아주캐피탈(주)           NaN
# 3    004372   44820                       코스맥스비티아이(주)  1.444120e+10
# 4    005398   23810                             (주)인팩  1.414313e+11
# 5    006394   25530                       (주)에스제이엠홀딩스  1.229431e+10
# 6    009288   28100                           (주)동아지질  2.927562e+11
# 7    015997   31820                          (주)콤텍시스템  1.453137e+11
# 8    019984  293480                           하나제약(주)  1.089422e+11
# 9    021987   39130                           (주)하나투어  3.600118e+11
# 10   024489   27410                           (주)비지에프  4.257634e+12
# 11   024524  234080                      제이더블유생명과학(주)  1.238798e+11
# 12   038869   77500                          유니퀘스트(주)  2.956671e+11
# ...
