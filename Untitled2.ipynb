# %%
from bs4 import BeautifulSoup

import requests

# %%
html_head = "https://www.op.gg/ranking/ladder/page="

page_no="1"

# %%
url = html_head + page_no

print(url)
# Out:
# https://www.op.gg/ranking/ladder/page=1

# %%
html = requests.get(url)


soup = BeautifulSoup(html.text, 'lxml')

soup
# Out:
# <!DOCTYPE html>
# <!--
# 	  ,ad8888ba,   88888888ba         ,ad8888ba,    ,ad8888ba,
# 	 d8"'    `"8b  88      "8b       d8"'    `"8b  d8"'    `"8b
# 	d8'        `8b 88      ,8P      d8'           d8'
# 	88          88 88aaaaaa8P'      88            88
# 	88          88 88""""""'        88      88888 88      88888
# 	Y8,        ,8P 88               Y8,        88 Y8,        88
# 	 Y8a.    .a8P  88                Y8a.    .a88  Y8a.    .a88
# 	  `"Y8888Y"'   88     dev@op.gg   `"Y88888P"    `"Y88888P"
#
# 		 Copyright © 2013-2020 OP.GG. All rights reserved.
# --><html lang="en_US">
# <head>
# <script>
# 		(function(t, l) {
# 			try {
# 				let w = window,
# 					d = document,
# 					s = d.createElement("script"),
# 					f = d.getElementsByTagName("script")[0];
# 				w[t] =
# 					w[t] ||
# 					function() {
# 						(w["_rgea"] = w["_rgea"] || [["uts", new Date()]]).push(
# 							Array.prototype.slice.call(arguments)
# 						);
# 						w.RGEA && w.RGEA.p();
# 					};
# ...

# %%
lasts = soup.find("div", "ranking-pagination__desc")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Kosmo_24'
