# %%
import pandas as pd

bs_1st = pd.read_excel('c:/chosungeun/d/bs_1st.xls')
bs_2nd = pd.read_excel('c:/chosungeun/d/bs_2nd.xls')
bs_3rd = pd.read_excel('c:/chosungeun/d/bs_3rd.xls')

# %%
bs_1st.head(10)
# Out:
#                           2010/1st Term(Jan~Mar) 2010/1st Term(Jan~Mar).1  \
# KIS    Stock  Name                   자산총계/115000              부채총계/118000
# 001402 036460 한국가스공사              22832500324000           17311574262000
# 001471 033780 (주)케이티앤지             4738779208000             999575620000
# 003316 033660 아주캐피탈(주)                       NaN                      NaN
# 004372 044820 코스맥스비티아이(주)           114240031000              70338016000
# 005398 023810 (주)인팩                  66609263000              29384503000
# 006394 025530 (주)에스제이엠홀딩스           202866980000              66749254000
# 009288 028100 (주)동아지질               195938900000              89205697000
# 015997 031820 (주)콤텍시스템               76383739000              36246369000
# 019984 293480 하나제약(주)                        NaN                      NaN
#
#                           2010/1st Term(Jan~Mar).2 2010/1st Term(Jan~Mar).3  \
# KIS    Stock  Name                     자본총계/118900           부채와자본총계/119000
# ...
