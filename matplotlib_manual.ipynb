# %% [markdown]
# # 1. Usage Guide

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# https://matplotlib.org/tutorials/introductory/usage.html#sphx.gir-tutoring

import numpy as np

import pandas as pd


print("pandas ver=", pd.__version__)
# Out:
# pandas ver= 0.25.1

# %%
from IPython.display import Image
Image("c:/홍길동/data/dog01.jpeg", width=300, height=200)

# %%
b = np.matrix([[1,2],[3,4]])
b_asarray = np.asarray(b)

# %%
a = pd.DataFrame(np.random.rand(4,5), columns = list('abcde'))

a_asarray = a.values
# Out:
#           a         b         c         d         e
# 0  0.091527  0.504674  0.727612  0.960817  0.851653
# 1  0.858966  0.147142  0.860057  0.823734  0.695880
# 2  0.617170  0.488111  0.251026  0.818177  0.844946
# 3  0.387895  0.665406  0.668230  0.179091  0.470477

# %%
b = np.matrix([[1,2],[3,4]])

b_asarray = np.asarray(b)

b_asarray
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
x = np.linspace(0,2,100) # 0부터 2까지 백등분을 하시오
x

plt.plot(x, x, label='linear') #1차식

plt.plot(x, x**2, label='quadratic') #2차식

plt.plot(x, x**3, label='cubic') # 3차식
 
plt.xlabel('x label')

plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend() # 범주

# %%
plt.plot([1,2,3], [1,2,3], 'rs', label='line2')

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)


plt.show()

# %%
def my_plotter(ax, data1, data2, param_dict):
    out = ax.plot(data1, data2, **param_dict)
    return out

data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {'marker': 'x', 'color' : 'green'})

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {'marker': "P"})
