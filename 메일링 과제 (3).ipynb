# %%
import smtplib
from email.mime.text import MIMEText

def sendMail(me, you, msg):
    smtp = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    smtp.login(me, 'wpztaveripgcigis') ####
    msg = MIMEText(msg)
    msg['Subject'] = 'your title'###
    smtp.sendmail(me, you, msg.as_string())
    smtp.quit()

sendMail('chosungeun4283@gmail.com', '', '메일텍스트') ####
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-1-40acbe72fdcc> in <module>
#      10     smtp.quit()
#      11
# ---> 12 sendMail('youremail@', 'recipient@', '메일텍스트') ####
#
# <ipython-input-1-40acbe72fdcc> in sendMail(me, you, msg)
#       4 def sendMail(me, you, msg):
#       5     smtp = smtplib.SMTP_SSL('smtp.gmail.com', 465)
# ----> 6     smtp.login(me, 'your password') ####
#       7     msg = MIMEText(msg)
#       8     msg['Subject'] = 'your title'###
#
# C:\Anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     728
#     729         # We could not login successfully.  Return result of last attempt.
# --> 730         raise last_exception
#     731
#     732     def starttls(self, keyfile=None, certfile=None, context=None):
#
# C:\Anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# --> 721                     initial_response_ok=initial_response_ok)
#     722                 # 235 == 'Authentication successful'
#     723                 # 503 == 'Error: already authenticated'
#
# C:\Anaconda3\lib\smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     640         if code in (235, 503):
#     641             return (code, resp)
# --> 642         raise SMTPAuthenticationError(code, resp)
#     643
#     644     def auth_cram_md5(self, challenge=None):
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. Learn more at\n5.7.8  https://support.google.com/mail/?p=BadCredentials d69sm2193364pfd.72 - gsmtp')

# %%
def get_news_list():
    '''현재 네이버 실시간 검색어 순위 20개를 가져옵니다.'''
    import requests
    import json

    url = 'https://www.naver.com/srchrank?frm=main&ag=20s&gr=0&ma=0&si=0&en=0&sp=0'
    res = json.loads(requests.get(url).content)
    rank = [*map(lambda item: item['keyword'], res['data'])]
    rank_list = []

    for i in range(len(rank)):
        ranks= i + 1
        rank_list.append(str(ranks) + '위 : ' + str(rank[i]))

    # rank_list


    return rank_list

# %%
import requests
from bs4 import BeautifulSoup
 
def get_melon_list():
    '''현재 멜론 인기곡 최신 54위를 반환합니다.'''
    RANK = 54
    rank_list = []
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
    req = requests.get('https://www.melon.com/chart/index.htm', headers = header)
    html = req.text
    parse = BeautifulSoup(html, 'html.parser')

    titles = parse.find_all("div", {"class": "ellipsis rank01"})
    songs = parse.find_all("div", {"class": "ellipsis rank02"})

    title = []
    song = []

    for t in titles:
        title.append(t.find('a').text)

    for s in songs:
        song.append(s.find('span', {"class": "checkEllipsis"}).text)

    for i in range(RANK):
        rank_list.append('%3d위: %s - %s'%(i+1, title[i], song[i]))
    return rank_list

# %%
get_melon_list()
# Out:
# ['  1위: 마음을 드려요 - 아이유',
#  '  2위: 아무노래 - 지코 (ZICO)',
#  '  3위: FIESTA - IZ*ONE (아이즈원)',
#  '  4위: METEOR - 창모 (CHANGMO)',
#  '  5위: 둘만의 세상으로 가 - Crush',
#  '  6위: 다시 난, 여기 - 백예린',
#  '  7위: Psycho - Red Velvet (레드벨벳)',
#  '  8위: Blueming - 아이유',
#  '  9위: 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey) - 방탄소년단',
#  ' 10위: 늦은 밤 너의 집 앞 골목길에서 - 노을',
#  ' 11위: Black Swan - 방탄소년단',
#  ' 12위: 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 - 장범준',
#  ' 13위: HIP - 마마무 (Mamamoo)',
#  ' 14위: 너를 사랑하고 있어 - 백현 (BAEKHYUN)',
#  ' 15위: 어떤 날엔 - 김재환',
#  ' 16위: 봄날 - 방탄소년단',
#  ' 17위: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU (악동뮤지션)',
#  ' 18위: 아마두 (feat.우원재, 김효은, 넉살, Huckleberry P) - 염따, 딥플로우, 팔로알토 (Paloalto), The Quiett, 사이먼 도미닉',
#  ' 19위: Flower - 윤미래',
#  ' 20위: 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온) - 마크툽 (MAKTUB)',
#  ' 21위: 빌었어 - 창모 (CHANGMO)',
#  ' 22위: Square (2017) - 백예린',
#  ' 23위: Love poem - 아이유',
#  ' 24위: 소우주 (Mikrokosmos) - 방탄소년단',
#  ' 25위: 시작 - 가호 (Gaho)',
#  ' 26위: 2002 - Anne-Marie',
#  ' 27위: 내 마음의 사진 - 송가인',
#  ' 28위: 마음이 말하는 행복 (Happiness) (Feat.이라온) - 마크툽 (MAKTUB)',
#  ' 29위: 안녕 - 폴킴',
#  ' 30위: IDOL - 방탄소년단',
#  ' 31위: 사랑이란 멜로는 없어 - 전상근',
#  ' 32위: 조금 취했어 (Prod. 2soo) - 임재현',
#  ' 33위: 다시는 사랑하지 않고, 이별에 아파하기 싫어 - 백지영',
#  ' 34위: 다시 만날까 봐 - V.O.S',
#  ' 35위: Make It Right - 방탄소년단',
#  ' 36위: 나의 오랜 연인에게 - 다비치',
#  ' 37위: 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴',
#  ' 38위: bad guy - Billie Eilish',
#  ' 39위: Dionysus - 방탄소년단',
#  ' 40위: 노을 - 다비치',
#  ' 41위: BAND - 창모 (CHANGMO), Hash Swan, ASH ISLAND, 김효은',
#  ' 42위: Señorita - Shawn Mendes, Camila Cabello',
#  ' 43위: ROXANNE - Arizona Zervas',
#  ' 44위: 우리 왜 헤어져야 해 - 신예영',
#  ' 45위: Birthday - Anne-Marie',
#  ' 46위: comethru - Jeremy Zucker',
#  ' 47위: Painkiller - Ruel',
#  ' 48위: Paris In The Rain - Lauv',
#  ' 49위: 잘 지내고 있는지 궁금해 - V.O.S',
#  ' 50위: 너를 만나 - 폴킴',
#  ' 51위: 시든 꽃에 물을 주듯 - HYNN (박혜원)',
#  ' 52위: 헤어진 우리가 지켜야 할 것들 - 김나영, 양다일',
#  ' 53위: 새 사랑 - 송하예',
#  ' 54위: 너의 하루는 좀 어때 - 거미']

# %% [markdown]
# # 과제: 위 컨텐츠  중 하나를 활용해,
# # 1) 네이버 실시간 검색어 순위 2) 멜론 차트 중 하나를 골라
#
# # mroboedu@gmail.com으로 5분마다 메일을 보내도록 해주세요!
#
# # 번외 : 만약이 위가 너무 쉽다면, 본인이 할 수 있는 분석 (자연어 분석, 웹크롤링) 등의 결과물을 실시간으로 메일링 하는 서비스를 만들어보아요!
#
# # 시간 : 1시간

# %%
import schedule
import time

# %%
def job():
    print("I'm working...")
    
schedule.every(10).seconds.do(job)
# Out:
# Every 10 seconds do job() (last run: [never], next run: 2020-02-20 16:45:22)

# %%
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-2d78333a8181> in <module>
#       1 while True:
#       2     schedule.run_pending()
# ----> 3     time.sleep(1)
#
# KeyboardInterrupt:
