# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv('c:/chosungeun/date.csv')
df.replace(0, np.nan)
df.head(5)
# Out:
#          Name    Date  유동자산계      현금및현금등가물           자본금         자본잉여금  \
# 0  (주)BNK금융지주  201102    NaN  5.189200e+07  9.670000e+11  1.640000e+12
# 1  (주)BNK금융지주  201103    NaN  8.984500e+07  9.670000e+11  1.640000e+12
# 2  (주)BNK금융지주  201104    NaN  1.700000e+11  9.670000e+11  1.640000e+12
# 3  (주)BNK금융지주  201201    NaN  7.087537e+10  9.670000e+11  1.640000e+12
# 4  (주)BNK금융지주  201202    NaN  2.433287e+09  9.670000e+11  1.640000e+12
#
#           이익잉여금  총자산증가율  자기자본증가율   매출액증가율  ...           자산총계          부채총계  \
# 0 -1.746391e+09    3.96    -0.06      NaN  ...   2.709760e+12  1.062570e+11
# 1 -4.219870e+09    7.41    -0.10      NaN  ...   2.910500e+12  3.094700e+11
# 2  1.230000e+11     NaN      NaN      NaN  ...   3.249910e+12  5.220900e+11
# 3  5.202239e+10   -0.09    -2.59      NaN  ...   3.247020e+12  5.897540e+11
# 4  4.672493e+10    2.27    -0.20  1549.44  ...   3.320850e+12  6.688780e+11
#
#            자본총계           매출액  매출총이익손실       판매비와관리비        영업이익손실  \
# ...

# %%
df['현금및현금등가물'].count()
# Out:
# 24855

# %%
unique_name=list(df['Name'].unique()) # 중복 제거
len_name=[]
for i in range(len(unique_name)):
    
    len_name.append(sum(df['Name']==unique_name[i]))

len_name
# Out:
# [31,
#  36,
#  36,
#  30,
#  36,
#  36,
#  36,
#  10,
#  21,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  33,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  29,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  6,
#  36,
#  36,
#  14,
#  36,
#  36,
#  36,
#  36,
#  35,
#  36,
#  12,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  35,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  35,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  35,
#  36,
#  34,
#  12,
#  36,
#  36,
#  8,
#  34,
#  36,
#  36,
#  36,
#  35,
#  36,
#  36,
#  36,
#  34,
#  36,
#  36,
#  36,
#  10,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  17,
#  35,
#  31,
#  35,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  36,
#  19,
#  32,
#  36,
#  36,
#  36,
#  36,
#  28,
#  36,
#  30,
#  36,
#  36,
#  36,
#  31,
#  36,
#  17,
#  36,
#  36,
#  32,
#  36,
#  36,
#  35,
#  31,
#  36,
#  36,
#  36,
#  36,
#  12,
#  11,
#  35,
#  36,
# ...

# %%
list_columns = df.columns[2:-2]
list_columns
# Out:
# Index(['유동자산계', '현금및현금등가물', '자본금', '자본잉여금', '이익잉여금', '총자산증가율', '자기자본증가율',
#        '매출액증가율', '비유동자산계', '영업이익증가율', '순이익증가율', '종업원수증가율', '매출액순이익율', '부채비율',
#        '총자본회전율', '자기자본회전율', '투자자산계', '유형자산계', '무형자산계', '유동부채계', '비유동부채계',
#        '총자본영업이익율', '총자본순이익율', '자기자본순이익율', '자본금순이익율', '자기자본비율', '자산총계', '부채총계',
#        '자본총계', '매출액', '매출총이익손실', '판매비와관리비', '영업이익손실', '당기순이익손실'],
#       dtype='object')

# %%
len_q=[[61, 60, 62, 61, 61, 60, 60, 62, 61, 59],
 [63, 62, 62, 62, 60, 62, 62, 60, 61, 62],
 [63, 63, 64, 62, 63, 64, 62, 64, 61, 63],
 [65, 63, 62, 62, 62, 63, 63, 57, 62, 62]]
working_day = []
for j in range(10):
    for i in range(len(len_q)):
        working_day.append(len_q[i][j])
working_day = working_day[1:-4]
len(working_day)
# Out:
# 35

# %%
working_day
# Out:
# [63,
#  63,
#  65,
#  60,
#  62,
#  63,
#  63,
#  62,
#  62,
#  64,
#  62,
#  61,
#  62,
#  62,
#  62,
#  61,
#  60,
#  63,
#  62,
#  60,
#  62,
#  64,
#  63,
#  60,
#  62,
#  62,
#  63,
#  62,
#  60,
#  64,
#  57,
#  61,
#  61,
#  61,
#  62]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-b10eb289ab84> in <module>
#       8     return a
#       9
# ---> 10 print(to_days('매출액'))
#
# <ipython-input-50-b10eb289ab84> in to_days(col_name)
#       5     for i in range(len(len_name)):
#       6         for j in range(len(new_name)-1):
# ----> 7             a.append((df[col_name][j+1] - df[col_name][j]) / working_day[-len_name[i]:][j])
#       8     return a
#       9
#
# IndexError: list index out of range
